# %% [markdown]
# <a href="https://colab.research.google.com/github/challa-sravya-26/DSA0403-Fundamental-of-data-science-/blob/main/Question4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 4: Banking Loan Approval Dataset

# %% [markdown]
# Create the Dataset

# %%
import pandas as pd

data = {
    "Customer_ID": ["C01","C02","C03","C04","C05","C06","C07","C08","C09","C10",
                    "C11","C12","C13","C14","C15","C16","C17","C18","C19","C20"],

    "Income": [45000,25000,60000,22000,50000,30000,70000,28000,55000,24000,
               65000,35000,48000,26000,75000,32000,52000,27000,68000,23000],

    "Credit_Score": [720,580,750,560,710,600,780,590,730,570,
                     760,620,700,585,790,610,725,575,770,555],

    "Loan_Amount": [200000,150000,300000,120000,250000,180000,350000,160000,270000,130000,
                    320000,200000,240000,140000,400000,190000,260000,150000,330000,125000],

    "Employment_Type": ["Salaried","Self-employed","Salaried","Unemployed","Salaried",
                        "Self-employed","Salaried","Self-employed","Salaried","Unemployed",
                        "Salaried","Self-employed","Salaried","Unemployed","Salaried",
                        "Self-employed","Salaried","Self-employed","Salaried","Unemployed"],

    "Loan_Status": ["Approved","Rejected","Approved","Rejected","Approved",
                    "Rejected","Approved","Rejected","Approved","Rejected",
                    "Approved","Rejected","Approved","Rejected","Approved",
                    "Rejected","Approved","Rejected","Approved","Rejected"]
}

df = pd.DataFrame(data)

# %% [markdown]
# Complete EDA

# %%
# Display Dataset
print(df)

# First and Last 5 Rows
print("\nFirst 5 Rows")
print(df.head())

print("\nLast 5 Rows")
print(df.tail())

# Shape
print("\nShape:", df.shape)

# Dataset Information
print("\nDataset Information")
df.info()

# Data Types
print("\nData Types")
print(df.dtypes)

# Missing Values
print("\nMissing Values")
print(df.isnull().sum())

# Duplicate Values
print("\nDuplicate Values:", df.duplicated().sum())

# Statistical Summary
print("\nStatistical Summary")
print(df.describe())

print("\nMean")
print(df.mean(numeric_only=True))

print("\nMedian")
print(df.median(numeric_only=True))

print("\nMinimum")
print(df.min(numeric_only=True))

print("\nMaximum")
print(df.max(numeric_only=True))

print("\nStandard Deviation")
print(df.std(numeric_only=True))
# Out:
#    Customer_ID  Income  Credit_Score  Loan_Amount Employment_Type Loan_Status
# 0          C01   45000           720       200000        Salaried    Approved
# 1          C02   25000           580       150000   Self-employed    Rejected
# 2          C03   60000           750       300000        Salaried    Approved
# 3          C04   22000           560       120000      Unemployed    Rejected
# 4          C05   50000           710       250000        Salaried    Approved
# 5          C06   30000           600       180000   Self-employed    Rejected
# 6          C07   70000           780       350000        Salaried    Approved
# 7          C08   28000           590       160000   Self-employed    Rejected
# 8          C09   55000           730       270000        Salaried    Approved
# 9          C10   24000           570       130000      Unemployed    Rejected
# 10         C11   65000           760       320000        Salaried    Approved
# ...

# %% [markdown]
# Data Visualizations

# %%
import matplotlib.pyplot as plt

# Bar Chart
status_count = df["Loan_Status"].value_counts()

plt.figure(figsize=(6,5))
plt.bar(status_count.index, status_count.values)
plt.title("Loan Approval Status")
plt.xlabel("Loan Status")
plt.ylabel("Number of Customers")
plt.show()

# Histogram
plt.figure(figsize=(6,4))
plt.hist(df["Credit_Score"], bins=6)
plt.title("Credit Score Distribution")
plt.xlabel("Credit Score")
plt.ylabel("Frequency")
plt.show()

# Scatter Plot
plt.figure(figsize=(6,5))
plt.scatter(df["Income"], df["Loan_Amount"])
plt.title("Income vs Loan Amount")
plt.xlabel("Income")
plt.ylabel("Loan Amount")
plt.show()

# Box Plot
plt.figure(figsize=(5,5))
plt.boxplot(df["Income"])
plt.title("Income Box Plot")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# Pattern Identification

# %%
print(df.groupby("Loan_Status")[["Income", "Credit_Score", "Loan_Amount"]].mean())

# %% [markdown]
# Observations
# 1. Customers with higher income were mostly approved for loans.
# 2. Approved applicants generally had credit scores above 700.
# 3. Rejected applicants had lower income and lower credit scores.
# 4. Salaried employees had a higher loan approval rate.
# 5. No missing values or duplicate records were found.

# %% [markdown]
# Conclusion
# The EDA shows that income, credit score, and employment type strongly influence loan approval decisions. Applicants with higher income and better credit scores were more likely to receive loan approval. The dataset is clean and suitable for analysis.
