# %% [markdown]
# <a href="https://colab.research.google.com/github/challa-sravya-26/DSA0403-Fundamental-of-data-science-/blob/main/Question3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 3: Retail Sales Dataset

# %% [markdown]
# Create the Dataset

# %%
import pandas as pd

data = {
    "Product_ID": ["PR01","PR02","PR03","PR04","PR05","PR06","PR07","PR08","PR09","PR10",
                   "PR11","PR12","PR13","PR14","PR15","PR16","PR17","PR18","PR19","PR20"],

    "Category": ["Grocery","Snacks","Dairy","Fruits","Vegetables","Grocery","Snacks","Dairy","Fruits","Vegetables",
                 "Grocery","Snacks","Dairy","Fruits","Vegetables","Grocery","Snacks","Dairy","Fruits","Vegetables"],

    "Price": [50,30,45,60,40,80,25,55,70,35,
              90,20,65,75,45,100,35,50,80,30],

    "Quantity_Sold": [20,35,18,25,30,15,40,16,22,28,
                      12,45,14,20,26,10,32,19,18,35],

    "Discount": [5,3,2,5,4,6,3,2,5,4,
                 6,2,3,5,4,7,3,2,6,3],

    "Revenue": [1000,1050,810,1500,1200,1200,1000,880,1540,980,
                1080,900,910,1500,1170,1000,1120,950,1440,1050]
}

df = pd.DataFrame(data)

# %% [markdown]
# Complete EDA

# %%
# Display Dataset
print(df)

# First and Last 5 Rows
print("\nFirst 5 Rows")
print(df.head())

print("\nLast 5 Rows")
print(df.tail())

# Shape
print("\nShape:", df.shape)

# Dataset Information
print("\nDataset Information")
df.info()

# Data Types
print("\nData Types")
print(df.dtypes)

# Missing Values
print("\nMissing Values")
print(df.isnull().sum())

# Duplicate Values
print("\nDuplicate Values:", df.duplicated().sum())

# Statistical Summary
print("\nStatistical Summary")
print(df.describe())

print("\nMean")
print(df.mean(numeric_only=True))

print("\nMedian")
print(df.median(numeric_only=True))

print("\nMinimum")
print(df.min(numeric_only=True))

print("\nMaximum")
print(df.max(numeric_only=True))

print("\nStandard Deviation")
print(df.std(numeric_only=True))
# Out:
#    Product_ID    Category  Price  Quantity_Sold  Discount  Revenue
# 0        PR01     Grocery     50             20         5     1000
# 1        PR02      Snacks     30             35         3     1050
# 2        PR03       Dairy     45             18         2      810
# 3        PR04      Fruits     60             25         5     1500
# 4        PR05  Vegetables     40             30         4     1200
# 5        PR06     Grocery     80             15         6     1200
# 6        PR07      Snacks     25             40         3     1000
# 7        PR08       Dairy     55             16         2      880
# 8        PR09      Fruits     70             22         5     1540
# 9        PR10  Vegetables     35             28         4      980
# 10       PR11     Grocery     90             12         6     1080
# 11       PR12      Snacks     20             45         2      900
# 12       PR13       Dairy     65             14         3      910
# ...

# %% [markdown]
# Data Visualizations

# %%
import matplotlib.pyplot as plt

# Bar Chart
category_revenue = df.groupby("Category")["Revenue"].sum()

plt.figure(figsize=(8,5))
plt.bar(category_revenue.index, category_revenue.values)
plt.title("Revenue by Category")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.show()

# Histogram
plt.figure(figsize=(6,4))
plt.hist(df["Price"], bins=6)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# Scatter Plot
plt.figure(figsize=(6,5))
plt.scatter(df["Quantity_Sold"], df["Revenue"])
plt.title("Quantity Sold vs Revenue")
plt.xlabel("Quantity Sold")
plt.ylabel("Revenue")
plt.show()

# Box Plot
plt.figure(figsize=(5,5))
plt.boxplot(df["Discount"])
plt.title("Discount Box Plot")
plt.ylabel("Discount")
plt.show()

# %% [markdown]
# Pattern Identification

# %%
print(df.groupby("Category")[["Price","Quantity_Sold","Revenue"]].mean())

# %% [markdown]
# Observations
# 1. Fruits generated the highest average revenue among all product categories.
# 2. Products with higher quantity sold generally earned higher revenue.
# 3. Grocery products had the highest average price.
# 4. Discounts varied across categories but did not always increase revenue.
# 5. The dataset contains no missing values or duplicate records.

# %% [markdown]
# Conclusion
# The EDA shows that product category, price, quantity sold, and discounts influence revenue. Fruits and Grocery products contribute significantly to sales revenue. The dataset is clean and suitable for analysis.
